# %%
import pandas as pd
df = pd.read_csv('IEA-methane-emissions-data.csv')

# %%
df.columns
# Out:
# Index(['region', 'country', 'emissions', 'source', 'type', 'segment', 'reason',
#        'baseYear', 'notes'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2122 entries, 0 to 2121
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   region     2122 non-null   object
#  1   country    2100 non-null   object
#  2   emissions  2122 non-null   float64
#  3   source     2122 non-null   object
#  4   type       2122 non-null   object
#  5   segment    2122 non-null   object
#  6   reason     2122 non-null   object
#  7   baseYear   2122 non-null   object
#  8   notes      2122 non-null   object
# dtypes: float64(1), object(8)
# memory usage: 149.3+ KB

# %%
df.isnull().sum()
# Out:
# region        0
# country      22
# emissions     0
# source        0
# type          0
# segment       0
# reason        0
# baseYear      0
# notes         0
# dtype: int64

# %%
df.loc[df['country'].isnull()]
# Out:
#      region country      emissions source         type  \
# 2100  World     NaN  141380.171900    IEA  Agriculture
# 2101  World     NaN    9140.847656    IEA       Energy
# 2102  World     NaN   11974.799800    IEA       Energy
# 2103  World     NaN    7143.020020    IEA       Energy
# 2104  World     NaN    3833.949951    IEA       Energy
# 2105  World     NaN    1555.109985    IEA       Energy
# 2106  World     NaN    3416.830078    IEA       Energy
# 2107  World     NaN    1434.630005    IEA       Energy
# 2108  World     NaN     559.791016    IEA       Energy
# 2109  World     NaN    7217.040039    IEA       Energy
# 2110  World     NaN    6560.700195    IEA       Energy
# 2111  World     NaN   14414.969730    IEA       Energy
# 2112  World     NaN    6916.100098    IEA       Energy
# 2113  World     NaN    1698.957031    IEA       Energy
# 2114  World     NaN   21903.589840    IEA       Energy
# 2115  World     NaN    3583.919922    IEA       Energy
# 2116  World     NaN    2478.947998    IEA       Energy
# 2117  World     NaN    3377.199951    IEA       Energy
# 2118  World     NaN   28021.300780    IEA       Energy
# 2119  World     NaN  135231.718800    IEA       Energy
# 2120  World     NaN    7277.776367    IEA        Other
# 2121  World     NaN   72999.453130    IEA        Waste
#
#                                segment    reason   baseYear  \
# 2100                             Total       All  2018-2019
# 2101                         Bioenergy       All       2021
# 2102                       Coking coal       All       2021
# 2103  Gas pipelines and LNG facilities  Fugitive       2021
# 2104  Gas pipelines and LNG facilities    Vented       2021
# 2105                      Offshore gas  Fugitive       2021
# 2106                      Offshore gas    Vented       2021
# 2107                      Offshore oil    Flared       2021
# 2108                      Offshore oil  Fugitive       2021
# 2109                      Offshore oil    Vented       2021
# 2110                       Onshore gas  Fugitive       2021
# 2111                       Onshore gas    Vented       2021
# 2112                       Onshore oil    Flared       2021
# 2113                       Onshore oil  Fugitive       2021
# 2114                       Onshore oil    Vented       2021
# 2115                   Other from coal       All       2021
# 2116            Other from oil and gas       All       2021
# 2117    Satellite-detected large leaks       All       2021
# 2118                        Steam coal       All       2021
# 2119                             Total       All       2021
# 2120                             Total       All  2018-2019
# 2121                             Total       All  2018-2019
#
#                                                   notes
# 2100  Average based on United Nations Framework Conv...
# 2101  Estimates from end-uses are for 2019 (IEA, Gre...
# 2102  Estimates from end-uses are for 2019 (IEA, Gre...
# 2103  Estimates from end-uses are for 2019 (IEA, Gre...
# 2104  Estimates from end-uses are for 2019 (IEA, Gre...
# 2105  Estimates from end-uses are for 2019 (IEA, Gre...
# 2106  Estimates from end-uses are for 2019 (IEA, Gre...
# 2107  Estimates from end-uses are for 2019 (IEA, Gre...
# 2108  Estimates from end-uses are for 2019 (IEA, Gre...
# 2109  Estimates from end-uses are for 2019 (IEA, Gre...
# 2110  Estimates from end-uses are for 2019 (IEA, Gre...
# 2111  Estimates from end-uses are for 2019 (IEA, Gre...
# 2112  Estimates from end-uses are for 2019 (IEA, Gre...
# 2113  Estimates from end-uses are for 2019 (IEA, Gre...
# 2114  Estimates from end-uses are for 2019 (IEA, Gre...
# 2115  Estimates from end-uses are for 2019 (IEA, Gre...
# 2116  Estimates from end-uses are for 2019 (IEA, Gre...
# 2117  Estimates from end-uses are for 2019 (IEA, Gre...
# 2118  Estimates from end-uses are for 2019 (IEA, Gre...
# 2119  Estimates from end-uses are for 2019 (IEA, Gre...
# 2120  Average based on United Nations Framework Conv...
# 2121  Average based on United Nations Framework Conv...

# %%
df = df.dropna()

# %%
df = df.drop(columns=['source','notes'])

# %%
df.to_csv('Updated-MethaneEmissionsData.csv')
